# %%
# from sklearn import svm,metrics
# from sklearn.neighbors import KNeighborsClassifier # 분류
# from sklearn.neighbors import KNeighborsRegressor  # 회귀-예측
from sklearn.linear_model import LinearRegression  # 선형회귀
from sklearn.preprocessing import PolynomialFeatures # 다항특성을 만들어주는 라이브러리
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False  # 마이너스 표시 해결
# 한글설정
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # windows 사용자
# matplotlib.rcParams['font.family'] = 'AppleGothic Gothic' # Mac사용자
matplotlib.rcParams['font.size'] = '10' # 글자크기

# %%
picher = pd.read_csv('picher_stats_2017.csv')
picher.shape
# Out:
# (152, 22)

# %%
picher.columns
# Out:
# Index(['선수명', '팀명', '승', '패', '세', '홀드', '블론', '경기', '선발', '이닝', '삼진/9',
#        '볼넷/9', '홈런/9', 'BABIP', 'LOB%', 'ERA', 'RA9-WAR', 'FIP', 'kFIP', 'WAR',
#        '연봉(2018)', '연봉(2017)'],
#       dtype='object')

# %%
# 데이터 확인

# nan,0, 타입, 데이터 간격
# str에 대한 데이터 분리
# picher.describe()
# picher.info()
# 결과값의 파악 : picher['연봉(2018)'] 
# hist그래프 출력
# 각각 피쳐간 상관관계 corr, heatmap
# - 피쳐간 관계 : 비슷한 피쳐는 삭제
# 각각 피쳐를 출력 subplots 각각 데이터 분포 파악 
# ( 0 데이터가 어느정도 있는지, 데이터 분포가 어떻게 되는지 )

# 결과값 파악

# %%
picher.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   선수명       152 non-null    object
#  1   팀명        152 non-null    object
#  2   승         152 non-null    int64
#  3   패         152 non-null    int64
#  4   세         152 non-null    int64
#  5   홀드        152 non-null    int64
#  6   블론        152 non-null    int64
#  7   경기        152 non-null    int64
#  8   선발        152 non-null    int64
#  9   이닝        152 non-null    float64
#  10  삼진/9      152 non-null    float64
#  11  볼넷/9      152 non-null    float64
#  12  홈런/9      152 non-null    float64
#  13  BABIP     152 non-null    float64
#  14  LOB%      152 non-null    float64
#  15  ERA       152 non-null    float64
#  16  RA9-WAR   152 non-null    float64
#  17  FIP       152 non-null    float64
#  18  kFIP      152 non-null    float64
#  19  WAR       152 non-null    float64
#  20  연봉(2018)  152 non-null    int64
#  21  연봉(2017)  152 non-null    int64
# dtypes: float64(11), int64(9), object(2)
# memory usage: 26.3+ KB

# %%
# str : 선수명,팀명

# %%
picher.describe()
# Out:
#                 승           패           세          홀드          블론          경기  \
# count  152.000000  152.000000  152.000000  152.000000  152.000000  152.000000
# mean     3.197368    3.157895    1.473684    2.644737    0.888158   28.848684
# std      3.863635    3.130929    4.808860    4.515474    1.633869   19.371502
# min      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000   14.000000
# 50%      2.000000    2.000000    0.000000    0.000000    0.000000   26.000000
# 75%      5.000000    6.000000    0.000000    3.000000    1.000000   41.000000
# max     20.000000   12.000000   37.000000   24.000000    7.000000   75.000000
#
#                선발          이닝        삼진/9        볼넷/9        홈런/9       BABIP  \
# count  152.000000  152.000000  152.000000  152.000000  152.000000  152.000000
# mean     6.092105   56.953947    7.049605    4.183289    1.209934    0.340507
# std      9.750093   50.297632    2.827552    2.362819    1.017072    0.088985
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   19.900000    5.492500    2.585000    0.690000    0.303750
# 50%      0.000000   43.700000    6.900000    3.750000    1.070000    0.333000
# 75%      7.000000   80.325000    8.212500    5.262500    1.550000    0.364000
# max     31.000000  193.100000   22.500000   18.000000    9.000000    0.833000
#
#              LOB%         ERA     RA9-WAR         FIP        kFIP         WAR  \
# count  152.000000  152.000000  152.000000  152.000000  152.000000  152.000000
# mean    68.523026    6.046053    1.056908    5.506842    5.536776    0.665921
# std     11.591590    4.166645    1.843708    1.871047    1.981596    1.322205
# min     35.700000    0.000000   -1.210000    0.730000   -0.690000   -1.010000
# 25%     62.400000    4.082500   -0.092500    4.437500    4.347500   -0.060000
# 50%     68.250000    5.355000    0.330000    5.210000    5.320000    0.130000
# 75%     74.525000    7.055000    1.522500    6.392500    6.570000    0.930000
# max    100.000000   36.000000    7.280000   18.730000   17.600000    6.620000
#
#             연봉(2018)       연봉(2017)
# count     152.000000     152.000000
# mean    18932.236842   16505.263158
# std     30940.732924   25046.478092
# min      2700.000000    2700.000000
# 25%      4000.000000    3000.000000
# 50%      7550.000000    6000.000000
# 75%     18500.000000   15250.000000
# max    230000.000000  150000.000000

# %%
picher['연봉(2018)'].sort_values()
# Out:
# 103      2700
# 93       2700
# 115      2700
# 82       2800
# 105      2800
#         ...
# 4      111000
# 20     120000
# 1      120000
# 0      140000
# 2      230000
# Name: 연봉(2018), Length: 152, dtype: int64

# %%
# 년봉 그래프
picher['연봉(2018)'].hist(bins=100)
# Out:
# <Axes: >

# %%
# 주식거래
picher.boxplot(column=['연봉(2018)'])
# Out:
# <Axes: >

# %%
picher.columns
# Out:
# Index(['선수명', '팀명', '승', '패', '세', '홀드', '블론', '경기', '선발', '이닝', '삼진/9',
#        '볼넷/9', '홈런/9', 'BABIP', 'LOB%', 'ERA', 'RA9-WAR', 'FIP', 'kFIP', 'WAR',
#        '연봉(2018)', '연봉(2017)'],
#       dtype='object')

# %%
#### picher DF
#### 선수명, 팀명 제외 DF
picher_features_df = picher.iloc[:,2:]

# %%
picher_features_df.columns
# Out:
# Index(['승', '패', '세', '홀드', '블론', '경기', '선발', '이닝', '삼진/9', '볼넷/9', '홈런/9',
#        'BABIP', 'LOB%', 'ERA', 'RA9-WAR', 'FIP', 'kFIP', 'WAR', '연봉(2018)',
#        '연봉(2017)'],
#       dtype='object')

# %%
import seaborn as sns

# %%
# method : pearson,kendall,spearman
corr = picher_features_df.corr(method='pearson')
show_cols = picher_features_df.columns
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # windows 사용자
plt.figure(figsize=(20,20))
# sns.set(font_scale=1.5)
sns.heatmap(corr.values,
            annot = True,
            yticklabels=show_cols,
            xticklabels=show_cols
            )
plt.tight_layout()
plt.show()

# %%
# 함수 사용해서 각각 그래프 출력
def plot_hist_each_column(df):
    matplotlib.rcParams['font.family'] = 'Malgun Gothic' # windows 사용자
    fig = plt.figure(figsize=(20,30))
    # plt.rcParams['figure.figsize'] = [20,30]
    # fig = plt.figure(1)
    for i in range(len(df.columns)):
        ax = fig.add_subplot(5,5,i+1)
        plt.hist(df[df.columns[i]],bins=50) # bins 그래프 폭
        ax.set_title(df.columns[i]) # 컬럼명을 타이틀로 사용

# %%
# subplot 여러개의 hist 출력 ( 5 * 5 )
# fig, axs = plt.subplots

# subplots, subplot, add_subplot, subplot2grid

# %%
plot_hist_each_column(picher_features_df)
# plt.figure(figsize=(20,20))
# plt.rcParams['figure.figsize'] = [20,20]
# fig = plt.figure(1)
# for i in range(len(picher_features_df.columns)):
#     ax = fig.add_subplot(5,5,i+1)
#     plt.hist(picher_features_df[picher_features_df.columns[i]],bins=50) # bins 그래프 폭
#     ax.set_title(picher_features_df.columns[i]) # 컬럼명을 타이틀로 사용

# %% [markdown]
# 데이터 확인

# %%
# picher - 모든 컬럼 존재
# picher_features_df - 이름, 팀명 분리
# 데이터 전처리

picher_result = picher_features_df['연봉(2018)']
picher_result

picher_y_df = picher_features_df.drop('연봉(2018)',axis=1) 
picher_y_df

# picher : 모든 컬럼 존재
# picher_features_df : 선수명,팀명 제외
# picher_y_df : 연봉(2018),선수명,팀명 제외
# Out:
#       승   패  세  홀드  블론  경기  선발     이닝  삼진/9  볼넷/9  홈런/9  BABIP  LOB%    ERA  \
# 0    16   7  0   0   0  30  30  190.0  8.95  2.13  0.76  0.342  73.7   3.60
# 1    11  11  1   0   0  30  29  185.1  7.43  1.85  0.53  0.319  67.1   3.88
# 2    20   6  0   0   0  31  31  193.1  7.36  2.09  0.79  0.332  72.1   3.44
# 3    10   7  0   0   0  28  28  175.2  8.04  1.95  1.02  0.298  75.0   3.43
# 4    13   7  0   0   0  30  30  187.1  7.49  2.11  0.91  0.323  74.1   3.80
# ..   ..  .. ..  ..  ..  ..  ..    ...   ...   ...   ...    ...   ...    ...
# 147   2   5  0   0   2  33   5   62.2  4.31  3.30  1.58  0.355  56.9   7.76
# 148   3   2  0   0   0  25  11   59.1  4.85  5.61  1.06  0.263  65.4   5.92
# 149   0   2  0   0   0   9   2   14.2  4.91  4.91  2.45  0.382  52.8  11.66
# 150   0   3  0   1   0  41   0   43.2  7.63  7.01  1.44  0.341  73.9   5.77
# 151   4   4  0   0   0  24  14   81.0  5.78  5.89  2.00  0.312  65.3   7.67
#
#      RA9-WAR   FIP  kFIP   WAR  연봉(2017)
# 0       6.91  3.69  3.44  6.62     85000
# 1       6.80  3.52  3.41  6.08     50000
# 2       6.54  3.94  3.82  5.64    150000
# 3       6.11  4.20  4.03  4.63    100000
# 4       6.13  4.36  4.31  4.38     85000
# ..       ...   ...   ...   ...       ...
# 147    -1.21  6.21  6.48 -0.47      8100
# 148     0.39  6.41  6.77 -0.49      3100
# 149    -0.83  8.03  8.29 -0.61     16000
# 150    -0.40  6.87  6.95 -0.70      2900
# 151    -0.68  7.60  7.81 -1.01      3000
#
# [152 rows x 19 columns]

# %%
# from sklearn.model_selection import train_test_split
# train_input,test_input,train_target,test_target = train_test_split(
#     picher_y_df,picher_result,random_state=42
# )

# %%
# 팀명 빠져 있음.

# %%
# 표준화 작업
# picher_y_scaled_df : 선수명,팀명,연봉(2018) 제외, 표준화작업 완료상태
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(picher_y_df)
picher_y_scaled_df = ss.transform(picher_y_df)

# %%
df_numpy = pd.DataFrame(picher_y_scaled_df)
df_numpy.columns = picher_y_df.columns
df_numpy.head()
# Out:
#           승         패         세        홀드        블론        경기        선발  \
# 0  3.324578  1.231202 -0.307465 -0.587641 -0.545389  0.059630  2.460174
# 1  2.026181  2.513001 -0.098828 -0.587641 -0.545389  0.059630  2.357272
# 2  4.363295  0.910752 -0.307465 -0.587641 -0.545389  0.111423  2.563077
# 3  1.766502  1.231202 -0.307465 -0.587641 -0.545389 -0.043956  2.254370
# 4  2.545540  1.231202 -0.307465 -0.587641 -0.545389  0.059630  2.460174
#
#          이닝      삼진/9      볼넷/9      홈런/9     BABIP      LOB%       ERA  \
# 0  2.653920  0.674321 -0.871873 -0.443844  0.016838  0.448091 -0.588996
# 1  2.556178  0.134976 -0.990767 -0.670731 -0.242485 -0.123170 -0.521574
# 2  2.715757  0.110138 -0.888857 -0.414250 -0.095911  0.309604 -0.627523
# 3  2.358699  0.351424 -0.948305 -0.187363 -0.479259  0.560612 -0.629931
# 4  2.596072  0.156266 -0.880365 -0.295875 -0.197386  0.482713 -0.540837
#
#     RA9-WAR       FIP      kFIP       WAR  연봉(2017)
# 0  3.185125 -0.974240 -1.061623  4.518029  2.743746
# 1  3.125265 -1.065398 -1.076813  4.108270  1.341724
# 2  2.983779 -0.840183 -0.869225  3.774393  5.347500
# 3  2.749783 -0.700764 -0.762899  3.007992  3.344612
# 4  2.760666 -0.614968 -0.621132  2.818289  2.743746

# %%
type(picher_y_scaled_df)
# Out:
# numpy.ndarray

# %%
# 선수명, 팀명 합치기
# concat 두 DataFrame 합치기
picher_y_scaled_nt_df = pd.concat([picher.iloc[:,:2],df_numpy],axis=1)
picher_y_scaled_nt_df

# picher : 모든 컬럼 존재
# picher_features_df : 선수명,팀명 제외
# picher_y_df : 연봉(2018),선수명,팀명 제외
# picher_result : 연봉(2018)
# picher_y_scaled_df : 선수명,팀명,연봉(2018) 제외, 표준화작업 완료상태
# picher_y_scaled_nt_df : 선수명,팀명포함 표준화작업 됨
# Out:
#      선수명   팀명         승         패         세        홀드        블론        경기  \
# 0     켈리   SK  3.324578  1.231202 -0.307465 -0.587641 -0.545389  0.059630
# 1     소사   LG  2.026181  2.513001 -0.098828 -0.587641 -0.545389  0.059630
# 2    양현종  KIA  4.363295  0.910752 -0.307465 -0.587641 -0.545389  0.111423
# 3    차우찬   LG  1.766502  1.231202 -0.307465 -0.587641 -0.545389 -0.043956
# 4    레일리   롯데  2.545540  1.231202 -0.307465 -0.587641 -0.545389  0.059630
# ..   ...  ...       ...       ...       ...       ...       ...       ...
# 147  장민재   한화 -0.310932  0.590302 -0.307465 -0.587641  0.682746  0.215009
# 148  정용운  KIA -0.051252 -0.371047 -0.307465 -0.587641 -0.545389 -0.199334
# 149  노경은   롯데 -0.830290 -0.371047 -0.307465 -0.587641 -0.545389 -1.028020
# 150  김승현   삼성 -0.830290 -0.050597 -0.307465 -0.365449 -0.545389  0.629352
# 151  류희운   KT  0.208427  0.269852 -0.307465 -0.587641 -0.545389 -0.251127
#
#            선발        이닝  ...      볼넷/9      홈런/9     BABIP      LOB%  \
# 0    2.460174  2.653920  ... -0.871873 -0.443844  0.016838  0.448091
# 1    2.357272  2.556178  ... -0.990767 -0.670731 -0.242485 -0.123170
# 2    2.563077  2.715757  ... -0.888857 -0.414250 -0.095911  0.309604
# 3    2.254370  2.358699  ... -0.948305 -0.187363 -0.479259  0.560612
# 4    2.460174  2.596072  ... -0.880365 -0.295875 -0.197386  0.482713
# ..        ...       ...  ...       ...       ...       ...       ...
# 147 -0.112380  0.104645  ... -0.375064  0.365057  0.163412 -1.006027
# 148  0.505033  0.042808  ...  0.605813 -0.147905 -0.873882 -0.270312
# 149 -0.421087 -0.852829  ...  0.308578  1.223282  0.467836 -1.360901
# 150 -0.626891 -0.274355  ...  1.200284  0.226952  0.005563  0.465402
# 151  0.813740  0.479656  ...  0.724707  0.779372 -0.321410 -0.278968
#
#           ERA   RA9-WAR       FIP      kFIP       WAR  연봉(2017)
# 0   -0.588996  3.185125 -0.974240 -1.061623  4.518029  2.743746
# 1   -0.521574  3.125265 -1.065398 -1.076813  4.108270  1.341724
# 2   -0.627523  2.983779 -0.840183 -0.869225  3.774393  5.347500
# 3   -0.629931  2.749783 -0.700764 -0.762899  3.007992  3.344612
# 4   -0.540837  2.760666 -0.614968 -0.621132  2.818289  2.743746
# ..        ...       ...       ...       ...       ...       ...
# 147  0.412709 -1.233602  0.377052  0.477566 -0.861951 -0.336696
# 148 -0.030353 -0.362917  0.484298  0.624396 -0.877127 -0.536985
# 149  1.351808 -1.026814  1.352985  1.393990 -0.968185 -0.020240
# 150 -0.066472 -0.792818  0.730962  0.715532 -1.036478 -0.544996
# 151  0.391038 -0.945187  1.122408  1.150961 -1.271710 -0.540991
#
# [152 rows x 21 columns]

# %%
picher_y_scaled_df = pd.DataFrame(picher_y_scaled_df)
picher_y_scaled_df.columns = picher_y_df.columns
picher_y_scaled_df
# Out:
#             승         패         세        홀드        블론        경기        선발  \
# 0    3.324578  1.231202 -0.307465 -0.587641 -0.545389  0.059630  2.460174
# 1    2.026181  2.513001 -0.098828 -0.587641 -0.545389  0.059630  2.357272
# 2    4.363295  0.910752 -0.307465 -0.587641 -0.545389  0.111423  2.563077
# 3    1.766502  1.231202 -0.307465 -0.587641 -0.545389 -0.043956  2.254370
# 4    2.545540  1.231202 -0.307465 -0.587641 -0.545389  0.059630  2.460174
# ..        ...       ...       ...       ...       ...       ...       ...
# 147 -0.310932  0.590302 -0.307465 -0.587641  0.682746  0.215009 -0.112380
# 148 -0.051252 -0.371047 -0.307465 -0.587641 -0.545389 -0.199334  0.505033
# 149 -0.830290 -0.371047 -0.307465 -0.587641 -0.545389 -1.028020 -0.421087
# 150 -0.830290 -0.050597 -0.307465 -0.365449 -0.545389  0.629352 -0.626891
# 151  0.208427  0.269852 -0.307465 -0.587641 -0.545389 -0.251127  0.813740
#
#            이닝      삼진/9      볼넷/9      홈런/9     BABIP      LOB%       ERA  \
# 0    2.653920  0.674321 -0.871873 -0.443844  0.016838  0.448091 -0.588996
# 1    2.556178  0.134976 -0.990767 -0.670731 -0.242485 -0.123170 -0.521574
# 2    2.715757  0.110138 -0.888857 -0.414250 -0.095911  0.309604 -0.627523
# 3    2.358699  0.351424 -0.948305 -0.187363 -0.479259  0.560612 -0.629931
# 4    2.596072  0.156266 -0.880365 -0.295875 -0.197386  0.482713 -0.540837
# ..        ...       ...       ...       ...       ...       ...       ...
# 147  0.104645 -0.972099 -0.375064  0.365057  0.163412 -1.006027  0.412709
# 148  0.042808 -0.780490  0.605813 -0.147905 -0.873882 -0.270312 -0.030353
# 149 -0.852829 -0.759200  0.308578  1.223282  0.467836 -1.360901  1.351808
# 150 -0.274355  0.205943  1.200284  0.226952  0.005563  0.465402 -0.066472
# 151  0.479656 -0.450496  0.724707  0.779372 -0.321410 -0.278968  0.391038
#
#       RA9-WAR       FIP      kFIP       WAR  연봉(2017)
# 0    3.185125 -0.974240 -1.061623  4.518029  2.743746
# 1    3.125265 -1.065398 -1.076813  4.108270  1.341724
# 2    2.983779 -0.840183 -0.869225  3.774393  5.347500
# 3    2.749783 -0.700764 -0.762899  3.007992  3.344612
# 4    2.760666 -0.614968 -0.621132  2.818289  2.743746
# ..        ...       ...       ...       ...       ...
# 147 -1.233602  0.377052  0.477566 -0.861951 -0.336696
# 148 -0.362917  0.484298  0.624396 -0.877127 -0.536985
# 149 -1.026814  1.352985  1.393990 -0.968185 -0.020240
# 150 -0.792818  0.730962  0.715532 -1.036478 -0.544996
# 151 -0.945187  1.122408  1.150961 -1.271710 -0.540991
#
# [152 rows x 19 columns]

# %%
type(picher_y_scaled_df)
# Out:
# pandas.core.frame.DataFrame

# %%
### 원핫인코딩후 팀명을 추가
# picher['팀명']
team_encoding = pd.get_dummies(picher['팀명'])
team_encoding
# picher_y_scaled_df : 선수명,팀명,연봉(2018) 제외, 표준화작업 완료상태
picher_y_scaled_df = picher_y_scaled_df.join(team_encoding)
picher_y_scaled_df
# Out:
#             승         패         세        홀드        블론        경기        선발  \
# 0    3.324578  1.231202 -0.307465 -0.587641 -0.545389  0.059630  2.460174
# 1    2.026181  2.513001 -0.098828 -0.587641 -0.545389  0.059630  2.357272
# 2    4.363295  0.910752 -0.307465 -0.587641 -0.545389  0.111423  2.563077
# 3    1.766502  1.231202 -0.307465 -0.587641 -0.545389 -0.043956  2.254370
# 4    2.545540  1.231202 -0.307465 -0.587641 -0.545389  0.059630  2.460174
# ..        ...       ...       ...       ...       ...       ...       ...
# 147 -0.310932  0.590302 -0.307465 -0.587641  0.682746  0.215009 -0.112380
# 148 -0.051252 -0.371047 -0.307465 -0.587641 -0.545389 -0.199334  0.505033
# 149 -0.830290 -0.371047 -0.307465 -0.587641 -0.545389 -1.028020 -0.421087
# 150 -0.830290 -0.050597 -0.307465 -0.365449 -0.545389  0.629352 -0.626891
# 151  0.208427  0.269852 -0.307465 -0.587641 -0.545389 -0.251127  0.813740
#
#            이닝      삼진/9      볼넷/9  ...  연봉(2017)    KIA     KT     LG     NC  \
# 0    2.653920  0.674321 -0.871873  ...  2.743746  False  False  False  False
# 1    2.556178  0.134976 -0.990767  ...  1.341724  False  False   True  False
# 2    2.715757  0.110138 -0.888857  ...  5.347500   True  False  False  False
# 3    2.358699  0.351424 -0.948305  ...  3.344612  False  False   True  False
# 4    2.596072  0.156266 -0.880365  ...  2.743746  False  False  False  False
# ..        ...       ...       ...  ...       ...    ...    ...    ...    ...
# 147  0.104645 -0.972099 -0.375064  ... -0.336696  False  False  False  False
# 148  0.042808 -0.780490  0.605813  ... -0.536985   True  False  False  False
# 149 -0.852829 -0.759200  0.308578  ... -0.020240  False  False  False  False
# 150 -0.274355  0.205943  1.200284  ... -0.544996  False  False  False  False
# 151  0.479656 -0.450496  0.724707  ... -0.540991  False   True  False  False
#
#         SK     두산     롯데     삼성     한화
# 0     True  False  False  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4    False  False   True  False  False
# ..     ...    ...    ...    ...    ...
# 147  False  False  False  False   True
# 148  False  False  False  False  False
# 149  False  False   True  False  False
# 150  False  False  False   True  False
# 151  False  False  False  False  False
#
# [152 rows x 28 columns]

# %%
type(picher_y_scaled_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(team_encoding)
# Out:
# pandas.core.frame.DataFrame

# %%
picher_y_scaled_df.columns
# Out:
# Index(['승', '패', '세', '홀드', '블론', '경기', '선발', '이닝', '삼진/9', '볼넷/9', '홈런/9',
#        'BABIP', 'LOB%', 'ERA', 'RA9-WAR', 'FIP', 'kFIP', 'WAR', '연봉(2017)',
#        'KIA', 'KT', 'LG', 'NC', 'SK', '두산', '롯데', '삼성', '한화'],
#       dtype='object')

# %%
picher_yy_scaled_df = picher_y_scaled_df.drop(['RA9-WAR','kFIP'],axis=1)
picher_yy_scaled_df.columns
# Out:
# Index(['승', '패', '세', '홀드', '블론', '경기', '선발', '이닝', '삼진/9', '볼넷/9', '홈런/9',
#        'BABIP', 'LOB%', 'ERA', 'FIP', 'WAR', '연봉(2017)', 'KIA', 'KT', 'LG',
#        'NC', 'SK', '두산', '롯데', '삼성', '한화'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# train_input,test_input,train_target,test_target = train_test_split(
#     picher_y_scaled_df,picher_result
# )
train_input,test_input,train_target,test_target = train_test_split(
    picher_yy_scaled_df,picher_result
)

# %%
train_input
# Out:
#             승         패         세        홀드        블론        경기        선발  \
# 142  0.208427 -0.050597  0.318446  1.189901  1.910881  1.250866 -0.626891
# 140 -0.830290 -0.371047 -0.307465 -0.365449 -0.545389  0.422180 -0.523989
# 70  -0.830290 -1.011947 -0.307465 -0.365449 -0.545389 -0.613677 -0.626891
# 47  -0.310932 -0.050597  0.318446  0.078937  3.139016  0.681144 -0.626891
# 87  -0.830290 -1.011947 -0.098828 -0.143256 -0.545389 -0.251127 -0.626891
# ..        ...       ...       ...       ...       ...       ...       ...
# 11   2.026181  0.910752 -0.307465 -0.365449 -0.545389  0.059630  2.357272
# 9    1.506823  1.231202 -0.307465 -0.587641 -0.545389  0.059630  2.357272
# 52   0.987464  0.269852 -0.307465  1.856479 -0.545389  2.079552 -0.626891
# 26   1.766502  0.910752 -0.307465  2.745250  0.682746  2.079552 -0.626891
# 135  0.468106  0.910752 -0.307465  2.745250  3.139016  1.768795 -0.626891
#
#            이닝      삼진/9      볼넷/9  ...  연봉(2017)    KIA     KT     LG     NC  \
# 142 -0.078871 -0.152438 -0.765717  ... -0.260586  False  False   True  False
# 140 -0.358134 -0.698879 -0.111799  ... -0.408800  False   True  False  False
# 70  -0.812934  0.755932 -0.400542  ...  0.220107  False  False   True  False
# 47  -0.218503  1.316566  0.134482  ... -0.500933  False  False  False  False
# 87  -0.413987 -0.585333 -1.254033  ... -0.460875  False  False  False  False
# ..        ...       ...       ...  ...       ...    ...    ...    ...    ...
# 11   2.618014 -0.705975 -0.944058  ...  1.341724  False  False  False  False
# 9    2.374656  0.092396 -0.931320  ...  2.142879   True  False  False  False
# 52   0.240287 -0.603074 -0.833657  ... -0.260586  False  False  False  False
# 26   0.643224  0.990121 -0.625592  ...  0.059876  False  False  False   True
# 135  0.322071  0.284006 -0.056598  ...  0.220107  False  False  False  False
#
#         SK     두산     롯데     삼성     한화
# 142  False  False  False  False  False
# 140  False  False  False  False  False
# 70   False  False  False  False  False
# 47    True  False  False  False  False
# 87   False  False  False  False   True
# ..     ...    ...    ...    ...    ...
# 11   False   True  False  False  False
# 9    False  False  False  False  False
# 52   False   True  False  False  False
# 26   False  False  False  False  False
# 135  False  False  False  False   True
#
# [114 rows x 26 columns]

# %%
# 데이터 학습시키기
lr = LinearRegression()
lr.fit(train_input,train_target)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
# Out:
# [ 3671.6544164   1887.20874028 -2120.78348871 -1974.96836798
#    936.5505594   1892.22667874 -2559.68519958 -7189.12728615
#  -2232.86831169  1964.27175187  2619.72016276  -586.69005599
#    321.54707095   340.8423514  -2647.24583511 15190.08872457
#  21989.75490242  1207.68725554  4497.1361522  -2038.36073625
#  -1058.78539259   277.78046787 -4060.68553899  -215.97862735
#   -380.65274076  1771.85916033]

# %%
print(lr.score(train_input,train_target))
print(lr.score(test_input,test_target))
# Out:
# 0.9521829191473952
# -0.15033201304793642

# %%
#### degree 추가해서 적용해 볼것

# %%
#### train세트 평가서 모듈 statsmodels
import statsmodels.api as sm

train_input = sm.add_constant(train_input)
model = sm.OLS(train_target.astype(int),train_input.astype(int)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               연봉(2018)   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     52.60
# Date:                Thu, 23 May 2024   Prob (F-statistic):           1.53e-42
# Time:                        18:10:33   Log-Likelihood:                -1196.0
# No. Observations:                 114   AIC:                             2444.
# Df Residuals:                      88   BIC:                             2515.
# Df Model:                          25
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6956.9761   1333.607      5.217      0.000    4306.712    9607.240
# 승           1.092e+04   2778.228      3.931      0.000    5400.654    1.64e+04
# 패           4037.9604   2114.261      1.910      0.059    -163.689    8239.610
# 세            686.7375   1661.177      0.413      0.680   -2614.504    3987.979
# 홀드          3793.3579   2272.107      1.670      0.099    -721.978    8308.694
# 블론          3226.6575   1687.425      1.912      0.059    -126.745    6580.059
# 경기          -407.2898   2609.181     -0.156      0.876   -5592.489    4777.909
# 선발         -2785.2840   4419.730     -0.630      0.530   -1.16e+04    5998.001
# 이닝         -2078.7019   3833.161     -0.542      0.589   -9696.304    5538.900
# 삼진/9       -2142.8242   1882.309     -1.138      0.258   -5883.518    1597.869
# 볼넷/9          94.6914   2188.115      0.043      0.966   -4253.728    4443.110
# 홈런/9        3300.9571   2688.627      1.228      0.223   -2042.124    8644.039
# BABIP      -1009.6600   2181.245     -0.463      0.645   -5344.425    3325.105
# LOB%         832.9291   1952.690      0.427      0.671   -3047.632    4713.490
# ERA         1439.1094   2445.098      0.589      0.558   -3420.009    6298.228
# FIP        -3710.9883   2953.988     -1.256      0.212   -9581.419    2159.442
# WAR         1.366e+04   2476.017      5.517      0.000    8739.341    1.86e+04
# 연봉(2017)    2.472e+04   1949.491     12.681      0.000    2.08e+04    2.86e+04
# KIA         -772.5757   2583.766     -0.299      0.766   -5907.268    4362.116
# KT          3632.4414   2977.498      1.220      0.226   -2284.710    9549.593
# LG         -1593.7294   2646.607     -0.602      0.549   -6853.306    3665.847
# NC          1966.3862   3384.376      0.581      0.563   -4759.350    8692.123
# SK          1085.2240   3025.744      0.359      0.721   -4927.807    7098.255
# 두산         -2658.8570   2991.758     -0.889      0.377   -8604.348    3286.634
# 롯데           337.2689   3005.934      0.112      0.911   -5636.393    6310.931
# 삼성          -637.7768   2745.312     -0.232      0.817   -6093.508    4817.954
# 한화          5598.5945   2613.897      2.142      0.035     404.023    1.08e+04
# ==============================================================================
# Omnibus:                       31.086   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.896
# Skew:                           0.970   Prob(JB):                     3.67e-19
# Kurtosis:                       6.756   Cond. No.                     1.94e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.04e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
### 평가서 를 그래프 출력
plt.figure(figsize=(20,20))
# 회귀 계수 - 기울기
coefs = model.params.tolist()
coefs_series = pd.Series(coefs)

# 변수명 - 특성이름
x_labels = model.params.index.tolist()

# 그래프 출력
plt.bar(x_labels,coefs_series)
plt.title('feature_coef_graph')
plt.xlabel('x_features')
plt.ylabel('coef')
plt.xticks(rotation=90)

plt.show()

# %%
# 회귀분석 예측 - 고려사항 체크
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# 각 피쳐마다 VIF 계수 출력
# target 어느정도 영향을 가했는지 확인
# 값이 높은 것은, 결과 예측에 많은 영향을 미쳤다라고 판단
vif = pd.DataFrame() # 선언
vif['VIF Factor'] = [ variance_inflation_factor(picher_yy_scaled_df.values.astype(float),i) for i in range(picher_yy_scaled_df.shape[1]) ]
vif['features'] = picher_yy_scaled_df.columns
vif.round(1)
# Out:
#     VIF Factor  features
# 0          7.6         승
# 1          5.3         패
# 2          2.7         세
# 3          3.6        홀드
# 4          2.9        블론
# 5         14.0        경기
# 6         39.1        선발
# 7         56.6        이닝
# 8         10.3      삼진/9
# 9         12.7      볼넷/9
# 10        38.4      홈런/9
# 11         3.2     BABIP
# 12         3.8      LOB%
# 13        10.4       ERA
# 14        62.8       FIP
# 15         7.0       WAR
# 16         2.5  연봉(2017)
# 17         1.1       KIA
# 18         1.1        KT
# 19         1.1        LG
# 20         1.1        NC
# 21         1.1        SK
# 22         1.2        두산
# 23         1.1        롯데
# 24         1.2        삼성
# 25         1.1        한화

# %%
#### ['FIP', 'WAR', '볼넷/9', '삼진/9', '연봉(2017)']
# 선형회귀 모델을 다시 실행해 보시오.
# print(picher_y_scaled_df.columns)
# print(picher_result)
new_df = picher_y_scaled_df[['FIP', 'WAR', '볼넷/9', '삼진/9', '연봉(2017)']]
new_df
picher_result.head()
# Out:
# 0    140000
# 1    120000
# 2    230000
# 3    100000
# 4    111000
# Name: 연봉(2018), dtype: int64

# %%
train_scaled,test_scaled,train_target,test_target = train_test_split(
    new_df,picher_result
)
train_scaled.head(2)
# Out:
#          FIP       WAR      볼넷/9      삼진/9  연봉(2017)
# 55 -0.314681 -0.216960  0.134482  0.890768  0.660742
# 50 -0.298594 -0.118315  0.661014  0.351424 -0.553008

# %%
# 데이터 실습시키기
lr = LinearRegression()
lr.fit(train_scaled,train_target)
# Out:
# LinearRegression()

# %%
print(lr.score(train_scaled,train_target))
print(lr.score(test_scaled,test_target))
# Out:
# 0.8953610969708783
# 0.8670624151777864

# %%
pre_df = picher[['FIP', 'WAR', '볼넷/9', '삼진/9', '연봉(2017)']]
pre_df.head()
# Out:
#     FIP   WAR  볼넷/9  삼진/9  연봉(2017)
# 0  3.69  6.62  2.13  8.95     85000
# 1  3.52  6.08  1.85  7.43     50000
# 2  3.94  5.64  2.09  7.36    150000
# 3  4.20  4.63  1.95  8.04    100000
# 4  4.36  4.38  2.11  7.49     85000

# %%
# 데이터 예측하기
pre_2018 = lr.predict(pre_df)

# %%
picher['예측연봉(2018)'] = pd.Series(pre_2018)

# %%
picher.columns
# Out:
# Index(['선수명', '팀명', '승', '패', '세', '홀드', '블론', '경기', '선발', '이닝', '삼진/9',
#        '볼넷/9', '홈런/9', 'BABIP', 'LOB%', 'ERA', 'RA9-WAR', 'FIP', 'kFIP', 'WAR',
#        '연봉(2018)', '연봉(2017)', '예측연봉(2018)'],
#       dtype='object')

# %%
# 작년연봉, 예측연봉, 실제연봉 출력
test_df = picher[['선수명','팀명','연봉(2017)','예측연봉(2018)','연봉(2018)']].head(10)
test_df
# Out:
#     선수명   팀명  연봉(2017)    예측연봉(2018)  연봉(2018)
# 0    켈리   SK     85000  1.496145e+09    140000
# 1    소사   LG     50000  8.801124e+08    120000
# 2   양현종  KIA    150000  2.640190e+09    230000
# 3   차우찬   LG    100000  1.760140e+09    100000
# 4   레일리   롯데     85000  1.496126e+09    111000
# 5  피어밴드   KT     35000  6.160810e+08     85000
# 6   고영표   KT      5200  9.157548e+07     11500
# 7   장원준   두산    100000  1.760134e+09    100000
# 8   함덕주   두산      7000  1.232562e+08     16000
# 9    팻딘  KIA     70000  1.232107e+09     70000

# %%
plt.figure(figsize=(30,10))
test_df.plot(x='선수명', y=['연봉(2017)', '예측연봉(2018)', '연봉(2018)'], kind="bar")
# Out:
# <Axes: xlabel='선수명'>
