# %%
import pandas as pd
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 3번    강호림  구로고  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN
# 6번    박동현  단지고  202   80  100   95  85  80           C
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85   90  95  95          c#

# %%
## 컬럼 삭제
df['합계'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기   합계
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python  455
# 2번    강태원  구로고  184   40   35   50  55  25        Java  205
# 3번    강호림  구로고  168   80   75   70  80  75  javascript  380
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN  325
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN   90
# 6번    박동현  단지고  202   80  100   95  85  80           C  440
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON  240
# 8번    승근열  단지고  190  100   85   90  95  95          c#  465

# %%
# 1개 컬럼 삭제
df.drop(columns=['합계'],inplace=True)
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 3번    강호림  구로고  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN
# 6번    박동현  단지고  202   80  100   95  85  80           C
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85   90  95  95          c#

# %%
# 여러개 컬럼 삭제
df.drop(columns=['국어','영어','수학'],inplace=True)
df
# Out:
#        이름   학교    키  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197  95  85      Python
# 2번    강태원  구로고  184  55  25        Java
# 3번    강호림  구로고  168  80  75  javascript
# 4번    김수찬  구로고  187  75  80         NaN
# 5번    김재욱  구로고  188  35  10         NaN
# 6번    박동현  단지고  202  85  80           C
# 7번    박혜정  단지고  188  40  35      PYTHON
# 8번    승근열  단지고  190  95  95          c#

# %%
import pandas as pd
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 3번    강호림  구로고  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN
# 6번    박동현  단지고  202   80  100   95  85  80           C
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85   90  95  95          c#

# %%
df.index
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
# 국어 점수 80점 이상
df['국어']>80
df[df['국어']>80].index
df.drop(index = df[df['국어']>80].index,inplace=True )
df
# Out:
#        이름   학교    키  국어   영어  수학  과학  사회        SW특기
# 지원번호
# 2번    강태원  구로고  184  40   35  50  55  25        Java
# 3번    강호림  구로고  168  80   75  70  80  75  javascript
# 4번    김수찬  구로고  187  40   60  70  75  80         NaN
# 5번    김재욱  구로고  188  15   20  10  35  10         NaN
# 6번    박동현  단지고  202  80  100  95  85  80           C
# 7번    박혜정  단지고  188  55   65  45  40  35      PYTHON

# %%
# columns 삭제 -> 정확한 컬럼명을 입력해야 삭제
# index 삭제 -> 정확한 index명을 입력해야 삭제

#  index 1개 삭제
df.drop(index='1번',inplace=True)
df
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회        SW특기
# 지원번호
# 2번    강태원  구로고  184   40   35  50  55  25        Java
# 3번    강호림  구로고  168   80   75  70  80  75  javascript
# 4번    김수찬  구로고  187   40   60  70  75  80         NaN
# 5번    김재욱  구로고  188   15   20  10  35  10         NaN
# 6번    박동현  단지고  202   80  100  95  85  80           C
# 7번    박혜정  단지고  188   55   65  45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85  90  95  95          c#

# %%
## 부분 수정
df.loc['5번','국어'] = 95
df
# Out:
#        이름   학교    키  국어   영어  수학  과학  사회        SW특기
# 지원번호
# 2번    강태원  구로고  184  40   35  50  55  25        Java
# 3번    강호림  구로고  168  80   75  70  80  75  javascript
# 4번    김수찬  구로고  187  40   60  70  75  80         NaN
# 5번    김재욱  구로고  188  95   20  10  35  10         NaN
# 6번    박동현  단지고  202  80  100  95  85  80           C
# 7번    박혜정  단지고  188  55   65  45  40  35      PYTHON

# %%
# index 여러 개 삭제
df.drop(index=['3번','5번'],inplace=True)
df
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# 2번    강태원  구로고  184   40   35  50  55  25    Java
# 4번    김수찬  구로고  187   40   60  70  75  80     NaN
# 6번    박동현  단지고  202   80  100  95  85  80       C
# 7번    박혜정  단지고  188   55   65  45  40  35  PYTHON
# 8번    승근열  단지고  190  100   85  90  95  95      c#

# %%
# 조건에 맞는 사람들만 삭제
filt = df['과학']<70
df.drop(index=df[filt].index,inplace=True)
df
# Out:
#        이름   학교    키  과학  사회 SW특기
# 지원번호
# 4번    김수찬  구로고  187  75  80  NaN
# 6번    박동현  단지고  202  85  80    C
# 8번    승근열  단지고  190  95  95   c#

# %%
# 수정
df['학교'] = df['학교'] + '등학교'
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고등학교  197   90   85  100  95  85      Python
# 2번    강태원  구로고등학교  184   40   35   50  55  25        Java
# 3번    강호림  구로고등학교  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고등학교  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고등학교  188   15   20   10  35  10         NaN
# 6번    박동현  단지고등학교  202   80  100   95  85  80           C
# 7번    박혜정  단지고등학교  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고등학교  190  100   85   90  95  95          c#

# %%
# 수정
df['학교'].replace({'구로고등학교':'디지털고','단지고등학교':'영등포고'},inplace=True)
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  디지털고  197   90   85  100  95  85      Python
# 2번    강태원  디지털고  184   40   35   50  55  25        Java
# 3번    강호림  디지털고  168   80   75   70  80  75  javascript
# 4번    김수찬  디지털고  187   40   60   70  75  80         NaN
# 5번    김재욱  디지털고  188   15   20   10  35  10         NaN
# 6번    박동현  영등포고  202   80  100   95  85  80           C
# 7번    박혜정  영등포고  188   55   65   45  40  35      PYTHON
# 8번    승근열  영등포고  190  100   85   90  95  95          c#

# %%
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
df['합계'] = df[df.columns[3]] + df[df.columns[4]] + df[df.columns[5]]+df[df.columns[6]]+df[df.columns[7]]

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기   합계
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python  455
# 2번    강태원  구로고  184   40   35   50  55  25        Java  205
# 3번    강호림  구로고  168   80   75   70  80  75  javascript  380
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN  325
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN   90
# 6번    박동현  단지고  202   80  100   95  85  80           C  440
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON  240
# 8번    승근열  단지고  190  100   85   90  95  95          c#  465

# %%
# df['합계'] = df[df.columns[3]] + df[df.columns[4]] + df[df.columns[5]]+df[df.columns[6]]+df[df.columns[7]]
df['합계'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기   결과   합계
# 지원번호
# 1번    강나래  디지털고  197   90   85  100  95  85      Python  불합격  455
# 2번    강태원  디지털고  184   40   35   50  55  25        Java  불합격  205
# 3번    강호림  디지털고  168   80   75   70  80  75  javascript  불합격  380
# 4번    김수찬  디지털고  187   40   60   70  75  80         NaN  불합격  325
# 5번    김재욱  디지털고  188   15   20   10  35  10         NaN  불합격   90
# 6번    박동현  영등포고  202   80  100   95  85  80           C  불합격  440
# 7번    박혜정  영등포고  188   55   65   45  40  35      PYTHON  불합격  240
# 8번    승근열  영등포고  190  100   85   90  95  95          c#  불합격  465

# %%
# 추가 후 수정
df['결과'] = '불합격'
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기   결과
# 지원번호
# 1번    강나래  디지털고  197   90   85  100  95  85      Python  불합격
# 2번    강태원  디지털고  184   40   35   50  55  25        Java  불합격
# 3번    강호림  디지털고  168   80   75   70  80  75  javascript  불합격
# 4번    김수찬  디지털고  187   40   60   70  75  80         NaN  불합격
# 5번    김재욱  디지털고  188   15   20   10  35  10         NaN  불합격
# 6번    박동현  영등포고  202   80  100   95  85  80           C  불합격
# 7번    박혜정  영등포고  188   55   65   45  40  35      PYTHON  불합격
# 8번    승근열  영등포고  190  100   85   90  95  95          c#  불합격
