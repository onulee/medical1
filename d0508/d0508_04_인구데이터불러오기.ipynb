# %%
import pandas as pd
df = pd.read_excel('20230103_인구.xlsx',skiprows=3,index_col='행정기관',usecols='B,E:Y')
df.head()
df.columns
df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         726,460  1,072,653  1,211,077  1,211,949  1,524,378  1,823,908
# 서울특별시      116,614    161,429    185,689    197,425    271,237    390,716
# 부산광역시       41,333     63,912     68,919     67,836     93,245    109,745
# 대구광역시       31,269     49,000     55,029     57,661     74,228     81,001
# 인천광역시       43,664     63,028     70,593     69,580     86,548    108,831
# 광주광역시       21,506     32,852     38,227     39,769     49,779     53,357
# 대전광역시       21,241     31,032     35,302     37,083     48,557     57,944
# 울산광역시       16,646     26,693     29,418     28,366     33,283     39,507
# 세종특별자치시      9,524     13,733     14,079     10,808      9,307     10,329
# ...

# %%
### rows데이터 불러오기

# df[0:1]
# df.iloc[0]
# df.head(3)
# df.tail(2)
# df[df.columns[-1]]

# df.iloc[0]   # 0번째 rows데이터 가져오기
# df.iloc[0].str # str타입으로 변경
# df.iloc[0].str.replace(",","") # replace함수를 사용해서 ,를 제거
df.iloc[0] = df.iloc[0].str.replace(",","").astype(int) 
df.iloc[0]
# Out:
# 0~4세        726460
# 5~9세       1072653
# 10~14세     1211077
# 15~19세     1211949
# 20~24세     1524378
# 25~29세     1823908
# 30~34세     1737714
# 35~39세     1684266
# 40~44세     2055130
# 45~49세     2039606
# 50~54세     2303096
# 55~59세     2052227
# 60~64세     2097254
# 65~69세     1554976
# 70~74세     1038388
# 75~79세      713448
# 80~84세      507915
# 85~89세      212726
# 90~94세       54180
# 95~99세        8880
# 100세 이상       1307
# Name: 전국  , dtype: object

# %%
df.describe()
# Out:
#           0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세   35~39세  \
# count       18       18       18       18       18       18       18       18
# unique      18       18       18       18       18       18       18       18
# top     726460  1072653  1211077  1211949  1524378  1823908  1737714  1684266
# freq         1        1        1        1        1        1        1        1
#
#          40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  75~79세  \
# count        18       18  ...       18       18       18       18      18
# unique       18       18  ...       18       18       18       18      18
# top     2055130  2039606  ...  2052227  2097254  1554976  1038388  713448
# freq          1        1  ...        1        1        1        1       1
#
#         80~84세  85~89세  90~94세  95~99세  100세 이상
# count       18      18      18      18       18
# unique      18      18      18      18       18
# top     507915  212726   54180    8880     1307
# ...

# %%
df.iloc[0]
# Out:
# 0~4세        726460
# 5~9세       1072653
# 10~14세     1211077
# 15~19세     1211949
# 20~24세     1524378
# 25~29세     1823908
# 30~34세     1737714
# 35~39세     1684266
# 40~44세     2055130
# 45~49세     2039606
# 50~54세     2303096
# 55~59세     2052227
# 60~64세     2097254
# 65~69세     1554976
# 70~74세     1038388
# 75~79세      713448
# 80~84세      507915
# 85~89세      212726
# 90~94세       54180
# 95~99세        8880
# 100세 이상       1307
# Name: 전국  , dtype: object

# %%
w_df = pd.read_excel('20230103_인구.xlsx',skiprows=3,index_col='행정기관',usecols='B,AB:AV')
w_df.head()
w_df.columns = df.columns
w_df.columns
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')
