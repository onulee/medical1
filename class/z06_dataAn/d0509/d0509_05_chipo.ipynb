# %%
import pandas as pd
filepath = '../z20_data/chipotle.tsv'
df = pd.read_csv(filepath,sep='\t')
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   object
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 180.7+ KB

# %%
# 컬럼의 타입 변경
df['order_id'] =  df['order_id'].astype(str)

# %%
# 달러 $ 부분을 삭제하시오.
# df['item_price'] = 0
df['item_price'] = df['item_price'].str.replace("$","").astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   object
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 180.7+ KB

# %%
df.head(30)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
# 10        5         1                    Chips and Guacamole
# 11        6         1                   Chicken Crispy Tacos
# 12        6         1                     Chicken Soft Tacos
# 13        7         1                           Chicken Bowl
# ...

# %%
df['order_id'].unique()
len(df['order_id'].unique())
# Out:
# 1834

# %%
df.shape
# Out:
# (4622, 5)

# %%
# 메뉴주문 
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df['item_name'].unique()
len(df['item_name'].unique())
# Out:
# 50

# %%
df['item_name'].count()
# Out:
# 4622

# %%
# df['item_name].count() : 전체개수
# item_name별 개별 개수확인
df['item_name'].value_counts()
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
item_count = df['item_name'].value_counts()
# zip()과 같은 형태로, value_count에 2개 컬럼을 1개 묶어 list저장
list(item_count.items())
# Out:
# [('Chicken Bowl', 726),
#  ('Chicken Burrito', 553),
#  ('Chips and Guacamole', 479),
#  ('Steak Burrito', 368),
#  ('Canned Soft Drink', 301),
#  ('Steak Bowl', 211),
#  ('Chips', 211),
#  ('Bottled Water', 162),
#  ('Chicken Soft Tacos', 115),
#  ('Chips and Fresh Tomato Salsa', 110),
#  ('Chicken Salad Bowl', 110),
#  ('Canned Soda', 104),
#  ('Side of Chips', 101),
#  ('Veggie Burrito', 95),
#  ('Barbacoa Burrito', 91),
#  ('Veggie Bowl', 85),
#  ('Carnitas Bowl', 68),
#  ('Barbacoa Bowl', 66),
#  ('Carnitas Burrito', 59),
#  ('Steak Soft Tacos', 55),
#  ('6 Pack Soft Drink', 54),
#  ('Chips and Tomatillo Red Chili Salsa', 48),
#  ('Chicken Crispy Tacos', 47),
#  ('Chips and Tomatillo Green Chili Salsa', 43),
#  ('Carnitas Soft Tacos', 40),
#  ('Steak Crispy Tacos', 35),
#  ('Chips and Tomatillo-Green Chili Salsa', 31),
#  ('Steak Salad Bowl', 29),
#  ('Nantucket Nectar', 27),
#  ('Barbacoa Soft Tacos', 25),
#  ('Chips and Roasted Chili Corn Salsa', 22),
#  ('Izze', 20),
# ...

# %%
import pandas as pd
filepath = '../z20_data/20230103_인구.xlsx'
df = pd.read_excel(filepath,skiprows=3,usecols='B,E:Y',index_col='행정기관')
df.head()
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       726,460  1,072,653  1,211,077  1,211,949  1,524,378  1,823,908
# 서울특별시    116,614    161,429    185,689    197,425    271,237    390,716
# 부산광역시     41,333     63,912     68,919     67,836     93,245    109,745
# 대구광역시     31,269     49,000     55,029     57,661     74,228     81,001
# 인천광역시     43,664     63,028     70,593     69,580     86,548    108,831
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       1,737,714  1,684,266  2,055,130  2,039,606  ...  2,052,227
# 서울특별시      379,852    332,153    363,795    352,011  ...    338,380
# ...

# %%
# df.iloc[0] = df.iloc[0].str.replace(",","").astype(int)
df.iloc[0] = df.iloc[0].str.replace(",","").astype(int)

# %%
df
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          726460  1072653  1211077  1211949  1524378  1823908  1737714
# 서울특별시      116,614  161,429  185,689  197,425  271,237  390,716  379,852
# 부산광역시       41,333   63,912   68,919   67,836   93,245  109,745  103,536
# 대구광역시       31,269   49,000   55,029   57,661   74,228   81,001   76,198
# 인천광역시       43,664   63,028   70,593   69,580   86,548  108,831  107,658
# 광주광역시       21,506   32,852   38,227   39,769   49,779   53,357   45,743
# 대전광역시       21,241   31,032   35,302   37,083   48,557   57,944   51,617
# 울산광역시       16,646   26,693   29,418   28,366   33,283   39,507   37,536
# 세종특별자치시      9,524   13,733   14,079   10,808    9,307   10,329   13,538
# 경기도        216,863  313,113  345,546  335,021  411,620  501,356  491,074
# 강원도         20,663   28,244   33,186   35,219   46,654   48,339   43,021
# 충청북도        22,631   32,948   37,693   37,809   47,397   57,064   51,561
# ...
