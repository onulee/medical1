# %%
import pandas as pd
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 3번    강호림  구로고  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN
# 6번    박동현  단지고  202   80  100   95  85  80           C
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85   90  95  95          c#

# %%
## 2개이상 조건 검색부분
lang = ['Python','Java']
filt = df['SW특기'].isin(lang)
df[filt]
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회    SW특기
# 지원번호
# 1번    강나래  구로고  197  90  85  100  95  85  Python
# 2번    강태원  구로고  184  40  35   50  55  25    Java

# %%
# startwith, contains, lower, upper
# 문자열함수 적용 - lower()
lang = ['python','java']
df['SW특기'].str.upper()
df['SW특기'].str.lower()
# python == ''
# 2개이상의 검색을 할수 있도록 함. isin 명령어 사용
filt = df['SW특기'].str.lower().isin(lang)
df[filt]
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회    SW특기
# 지원번호
# 1번    강나래  구로고  197  90  85  100  95  85  Python
# 2번    강태원  구로고  184  40  35   50  55  25    Java
# 7번    박혜정  단지고  188  55  65   45  40  35  PYTHON

# %%
df['SW특기'].str.lower().isin(lang)
# Out:
# 지원번호
# 1번     True
# 2번     True
# 3번    False
# 4번    False
# 5번    False
# 6번    False
# 7번     True
# 8번    False
# Name: SW특기, dtype: bool

# %%
df
# Out:
#             id  kor  eng  math  total        avg  rank      c_date
# no
# 1      Joelynn   55   87    68    210  70.000000     0  2024-04-04
# 2       Bambie   73   69    77    219  73.000000     0  2024-04-01
# 3         Orin   92   97    90    279  93.000000     0  2024-04-04
# 4         Puff   98   60    78    236  78.666667     0  2024-04-04
# 5      Godfree   66   72    59    197  65.666667     0  2024-04-06
# ...        ...  ...  ...   ...    ...        ...   ...         ...
# 996    Wilburt   59   64    51    174  58.000000     0  2024-04-01
# 997    Broddie   89   53    54    196  65.333333     0  2024-04-06
# 998     Baxter   63   82    78    223  74.333333     0  2024-04-02
# 999    Ignacio   61   60    96    217  72.333333     0  2024-04-07
# 1000  Wallache   83   64    56    203  67.666667     0  2024-04-08
#
# [1000 rows x 8 columns]

# %%
# java라는 글자가 포함되어 있는 것을 검색
# na = False, Nan데이터를 True,False처리해 줌.
# startwith, contains, lower 문자열함수
# filt = df['SW특기'].str.lower().str.contains('java',na=True)
filt = df['SW특기'].str.lower().str.contains('java',na=False)
df[filt]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SW특기'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 5
#       1 # java라는 글자가 포함되어 있는 것을 검색
# ...

# %%
import pandas as pd
df = pd.read_csv('../z20_data/stu_score1.csv',index_col='no')
df
# Out:
#             id  kor  eng  math  total        avg  rank      c_date
# no
# 1      Joelynn   55   87    68    210  70.000000     0  2024-04-04
# 2       Bambie   73   69    77    219  73.000000     0  2024-04-01
# 3         Orin   92   97    90    279  93.000000     0  2024-04-04
# 4         Puff   98   60    78    236  78.666667     0  2024-04-04
# 5      Godfree   66   72    59    197  65.666667     0  2024-04-06
# ...        ...  ...  ...   ...    ...        ...   ...         ...
# 996    Wilburt   59   64    51    174  58.000000     0  2024-04-01
# 997    Broddie   89   53    54    196  65.333333     0  2024-04-06
# 998     Baxter   63   82    78    223  74.333333     0  2024-04-02
# 999    Ignacio   61   60    96    217  72.333333     0  2024-04-07
# 1000  Wallache   83   64    56    203  67.666667     0  2024-04-08
#
# [1000 rows x 8 columns]

# %% [markdown]
# #### ID에 대소문자 구분없이 i가 들어가 있는 학생을 검색하시오
# #### ID에 all 이 포함되어 있으면서 평균이 67점 이상인 학생을 검색하시오.

# %%
filt = df['id'].str.lower().str.contains('i')
len(df[filt])
df.loc[~filt,'id'].head(10)
# Out:
# no
# 1     Joelynn
# 4        Puff
# 5     Godfree
# 6       Penny
# 9       Flora
# 11    Atlante
# 17      Tally
# 19     Evelyn
# 20      Chere
# 21      Jobye
# Name: id, dtype: object

# %%
filt = (df['id'].str.lower().str.contains('all')) & (df['avg'] > 80)
# filt = (df['avg'] > 67)
len(df[filt])
df[filt]
# Out:
#            id  kor  eng  math  total        avg  rank      c_date
# no
# 17      Tally   77  100    81    258  86.000000     0  2024-04-01
# 106  Mallorie   89   91    62    242  80.666667     0  2024-04-09
# 434     Allie  100   54    90    244  81.333333     0  2024-04-06
# 485     Allis   81   84    76    241  80.333333     0  2024-04-06
# 772    Sallie   74   82    88    244  81.333333     0  2024-04-05
