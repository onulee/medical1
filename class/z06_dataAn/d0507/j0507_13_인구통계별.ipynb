# %% [markdown]
# ### 인구별 통계자료 불러오기

# %%
import pandas as pd
# 한글인코딩 - utf-8, euc-kr
df = pd.read_csv('data1.csv',encoding='euc-kr',skiprows=1,nrows=8)

df
# Out:
#         전국  (0000000000) 51,285,153 51,285,153.1 3,259,937 4,634,906  \
# 0    서울특별시  (1100000000)  9,378,269    9,378,269   502,083   731,176
# 1    부산광역시  (2600000000)  3,284,947    3,284,947   189,986   263,058
# 2    대구광역시  (2700000000)  2,368,670    2,368,670   147,411   212,696
# 3    인천광역시  (2800000000)  3,008,484    3,008,484   199,976   271,930
# 4    광주광역시  (2900000000)  1,414,862    1,414,862    97,121   146,430
# 5    대전광역시  (3000000000)  1,441,272    1,441,272    94,665   137,121
# 6    울산광역시  (3100000000)  1,101,059    1,101,059    76,781   109,050
# 7  세종특별자치시  (3600000000)    387,726      387,726    42,795    51,145
#
#    6,110,713  6,573,833  7,847,315  8,726,337  7,713,462  ... 2,251,029  \
# 0  1,345,398  1,429,039  1,407,189  1,497,051  1,323,231  ...   357,633
# 1    370,874    389,467    479,849    541,104    562,481  ...   128,223
# 2    276,301    280,390    351,733    420,183    369,956  ...   103,179
# ...
