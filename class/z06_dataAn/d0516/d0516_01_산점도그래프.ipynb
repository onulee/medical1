# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
matplotlib.rcParams['axes.unicode_minus'] = False  # 마이너스 표시 해결
# 한글설정
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # windows 사용자
# matplotlib.rcParams['font.family'] = 'AppleGothic Gothic' # Mac사용자
matplotlib.rcParams['font.size'] = '10' # 글자크기

# %%
import pandas as pd
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df.head(3)
# Out:
#        이름   학교  학년    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고   3  197  90  85  100  95  85      Python
# 2번    강태원  구로고   3  184  40  35   50  55  25        Java
# 3번    강호림  구로고   2  168  80  75   70  80  75  javascript

# %%
plt.bar(df['이름'],df['국어'])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.plot(df['이름'],df['영어'])
plt.plot(df['이름'],df['수학'])

# %%
# 산점도 그래프
plt.scatter(df['영어'],df['수학'])
plt.xlabel('영어점수')
plt.ylabel('수학점수')
# Out:
# Text(0, 0.5, '수학점수')

# %%
df.columns
# Out:
# Index(['이름', '학교', '학년', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
plt.scatter(df['영어'],df['수학'])
plt.scatter(df['영어'],df['과학'])

# %%
df['학년']
# Out:
# 지원번호
# 1번    3
# 2번    3
# 3번    2
# 4번    1
# 5번    1
# 6번    3
# 7번    2
# 8번    2
# Name: 학년, dtype: int64

# %%
# 산점도 그래프
plt.scatter(df['영어'],df['수학'])
plt.xlabel('영어점수')
plt.ylabel('수학점수')
# Out:
# Text(0, 0.5, '수학점수')

# %%
np.random.rand(8)*1000
# Out:
# array([592.04121774, 964.85038241, 952.05517162,  49.26856051,
#        106.52805049, 730.42738512, 265.71932235, 485.58607781])

# %%
sizes = np.random.rand(8)*1000
# s는 산점도 그래프 점의 크기 조절
plt.scatter(df['영어'],df['수학'],s=1000)

# %%
sizes = np.random.rand(8)*1000
plt.scatter(df['영어'],df['수학'],s=sizes)

# %%
# 학년별 크기조절 1*500=500, 2*500=1000, 3*500=1500
sizes = df['학년']*500
plt.scatter(df['영어'],df['수학'],s=sizes)
plt.xlabel('영어점수')
plt.ylabel('수학점수')
# Out:
# Text(0, 0.5, '수학점수')

# %%
# 학년별 크기조절 1*500=500, 2*500=1000, 3*500=1500
sizes = df['학년']*500
plt.scatter(df['영어'],df['수학'],s=sizes,c=df['학년'],cmap='viridis')
plt.xlabel('영어점수')
plt.ylabel('수학점수')
# 컬러바 눈금표시 : ticks, 라벨표시 : label, 컬러바크기조절 : shrink, 컬러바 위치 하단배치 : orientation
plt.colorbar(ticks=[1,2,3],label='학년',shrink=0.3, orientation='horizontal')

# %%
# stu_score1.csv 50명의 이름,합계점수 산점도 그래프를 출력하시오.
# x축 이름은 90도로 돌려서 출력하시오.

# %%
import pandas as pd
df = pd.read_csv('../z20_data/stu_score1.csv')
df = df.head(20)

# %%
plt.scatter(df['id'],df['total'])
plt.xlabel('ID')
plt.ylabel('합계점수')
plt.xticks(rotation=90)

plt.show()
